# %%
#Daframes estructuras de dimensiones, como crear un dat frame en pandas 
#manual
#leyendo un fichero

import pandas as pd,
clase= pd.DataFrame([{"Nombre":"Pedro":"Edad" 27,"Estatura":1.75},
                     {"Nombre":"Andrea":"Edad" 20,"Estatura":1.65},
                     {"Nombre":"Marina":"Edad" 58,"Estatura":1.58},
                     {"Nombre":"Marina":"Edad" 32,"Estatura":1.78},
                     {"Nombre":"Marina":"Edad" 35,"Estatura":1.68}])
# Out:
#   Cell In[38], line 5
#     import pandas as pd,
#                         ^
# SyntaxError: invalid syntax

# %%
#Como trabajar con un solo campo del data frame, nombre del data frame,
#corchete y el nombre del campo entre comillas

clase["nombre"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 #Como trabajar con un solo campo del data frame, nombre del data frame,
#       2 #corchete y el nombre del campo entre comillas
# ----> 4 clase["nombre"]
#
# NameError: name 'clase' is not defined

# %%
clase["edad"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 clase["edad"]
#
# NameError: name 'clase' is not defined

# %%
clase["edad"].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 clase["edad"].max()
#
# NameError: name 'clase' is not defined

# %%
clase ["edad"].sum
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 clase ["edad"].sum
#
# NameError: name 'clase' is not defined

# %%
clase["estatura"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 clase["estatura"].mean()
#
# NameError: name 'clase' is not defined

# %%
#como añadir una columna
#1.-con un valor unico - puesto de manera manual
#2.-mediante un calculo con otra columna del dataframe
clase["edad"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 #como añadir una columna
#       2 #1.-con un valor unico - puesto de manera manual
#       3 #2.-mediante un calculo con otra columna del dataframe
# ----> 4 clase["edad"]
#
# NameError: name 'clase' is not defined

# %%
#PRACTICA1.- REAR una nueva columna en el dataframe que me reste 10 centimetro
#A la altura de cada columna
clase["estatura"]=clase["estatura"]-0.10
clase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #PRACTICA1.- REAR una nueva columna en el dataframe que me reste 10 centimetro
#       2 #A la altura de cada columna
# ----> 3 clase["estatura"]=clase["estatura"]-0.10
#       4 clase
#
# NameError: name 'clase' is not defined

# %%
def restaredad(x):
    ifx<40:
        return x-2
    else:
        return x-4
# Out:
#   Cell In[14], line 2
#     ifx<40:
#           ^
# SyntaxError: invalid syntax

# %%
#como aplicar una funcion a todos los registros o filas de un dataframe
#con Apply

clase[edad4]=clase["edad"].apply(restaredad)
clase
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 #como aplicar una funcion a todos los registros o filas de un dataframe
#       2 #con Apply
# ----> 4 clase[edad4]=clase["edad"].apply(restaredad)
#       5 clase
#
# NameError: name 'clase' is not defined

# %%
#crear un data frame con los siguientes datos
#cliente = cliente1,Ventas = 2800
#cliente = cliente2,Ventas = 3450
#cliente = cliente3,Ventas = 1870
#cliente = cliente4,Ventas = 2458
#cliente = cliente5,Ventas = 6053
#cliente = cliente6,Ventas = 5382
#cliente = cliente7,Ventas = 7105
#añadir una columna llamada zona con el valor = Zona este
#Añadir una columna llamada descuento 1 con el importe correspondiente
#Al 3% sobre las ventas --> los decimales con punto
#Añadir una columna llamada descuento 2, con el 2% sobre las ventas si las
#ventas son menores 3000E, aplicar un 2,5% sobre las ventas si estas 
#estan 3000-5500, aplicar un 2,75% sobre las ventas si estas son 
#mayores de 5500
#añadir una columna llamda ventas Neto = Ventas - Descuento1 - Descuento2
#montar un texto que nos diga el promedio de ventas 
#montar un texto que nos diga la suma de ventas netas
#montar un texto que nos diga la suma de descuento 
#montar un texto que diga el descuento 1 mas grande

# %%
import pandas as pd
cliente=pd.DataFrame ([{"cliente": "cliente1", "Ventas": 2800},
                       {"cliente": "cliente2", "Ventas": 3450},
                       {"cliente": "cliente3", "Ventas": 1870},
                       {"cliente": "cliente4", "Ventas": 2458},
                       {"cliente": "cliente5", "Ventas": 6053},
                       {"cliente": "cliente6", "Ventas": 5382},
                       {"cliente": "cliente7", "Ventas": 7105}])

# %%
cliente
# Out:
#     cliente  Ventas
# 0  cliente1    2800
# 1  cliente2    3450
# 2  cliente3    1870
# 3  cliente4    2458
# 4  cliente5    6053
# 5  cliente6    5382
# 6  cliente7    7105

# %%
cliente = cliente.drop(["cliente1"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 cliente = cliente.drop(["cliente1"],axis=1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
#eliminar una fila con su indice, tambien con drop
clientes = cliente.drop([2],axis=0)
cliente
# Out:
#     cliente  Ventas
# 0  cliente1    2800
# 1  cliente2    3450
# 2  cliente3    1870
# 3  cliente4    2458
# 4  cliente5    6053
# 5  cliente6    5382
# 6  cliente7    7105

# %%
#vamos a cargar un data frame con los datos de los pasajeros del titanic
#el primer paso es pobner el fichero en Jupyter lab
import pandas as pd
titanic=pd.read_csv("Titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                                Pepe, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
#informacion acerca de la estructura del datafRAME
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 83.7+ KB

# %%
#ver los primeros 10 registros con
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                              Pepe, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male  NaN      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %%
#ver los ultimos 10 registros con tail()
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#como ver los primeros 10m  nombres del dataframe
titanic["Name"].head(10)
# Out:
# 0                                Pepe, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
#practica de las 5 ultimas edad3es 
#ver los primeros 15 de ticket

# %%
titanic["Ticket"].head(15)
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# Name: Ticket, dtype: object

# %%
titanic["Age"].tail(5)
# Out:
# 886     27
# 887     19
# 888    NaN
# 889     26
# 890     32
# Name: Age, dtype: object

# %%
#Como aplicar un filtro a un DataFrame
#Se recomienda gaurdar el filtro en un objeto,
#como ver solamente los pasajeros de la clase 2
titanicC2=titanic["Pclass"]==2
titanicC2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
titanic[titanicC2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female   14      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female   55      0      0
# 17                   Williams, Mr. Charles Eugene    male  NaN      0      0
# 20                           Fynney, Mr. Joseph J    male   35      0      0
# 21                          Beesley, Mr. Lawrence    male   34      0      0
# ...

# %%
titanicDC2=titanic[titanicC2]
titanicDC2
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female   14      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female   55      0      0
# 17                   Williams, Mr. Charles Eugene    male  NaN      0      0
# 20                           Fynney, Mr. Joseph J    male   35      0      0
# 21                          Beesley, Mr. Lawrence    male   34      0      0
# ...

# %%
#ver los ultimos 5 nombres ordenados ascendente
titanicDC2["Name"].tail(5).sort_values(ascending=True)
# Out:
# 874           Abelson, Mrs. Samuel (Hannah Wizosky)
# 883                   Banfield, Mr. Frederick James
# 866                    Duran y More, Miss. Asuncion
# 886                           Montvila, Rev. Juozas
# 880    Shelley, Mrs. William (Imanita Parrish Hall)
# Name: Name, dtype: object

# %%
#Practica queremos ver en una lista ordenada en orden descendente los numeros de ticket  
#de los pasdajeros que sobrevieron 
#Survived = 0 (No vivio / Survived = 1 (si vivió)

#PRACTICA queremos ver una lista ordenada en orden 
#ascendete los nombres de los pasajeros que no eran de la clase 1

# %%
titanicS1=titanic["Survived"]==1
titanicDS1 = titanic[titanicS1]
titanicDS1["Ticket"].sort_values(ascending=False)
# Out:
# 540           WE/P 5735
# 526         W./C. 14258
# 226           SW/PP 751
# 216    STON/O2. 3101283
# 2      STON/O2. 3101282
#              ...
# 585              110413
# 558              110413
# 504              110152
# 759              110152
# 257              110152
# Name: Ticket, Length: 342, dtype: object

# %%
titanicNC1=titanic["Pclass"]!=1 
titanicDNC1=titanic[titanicNC1]
titanicDNC1["Name"].sort_values(ascending=True)
# Out:
# 845                      Abbing, Mr. Anthony
# 746              Abbott, Mr. Rossmore Edward
# 279         Abbott, Mrs. Stanton (Rosa Hunt)
# 308                      Abelson, Mr. Samuel
# 874    Abelson, Mrs. Samuel (Hannah Wizosky)
#                        ...
# 286                  de Mulder, Mr. Theodore
# 282                de Pelsmaeker, Mr. Alfons
# 361                del Carlo, Mr. Sebastiano
# 153          van Billiard, Mr. Austin Blyler
# 868              van Melkebeke, Mr. Philemon
# Name: Name, Length: 675, dtype: object

# %%
titanicDS1.count()
# Out:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            290
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Cabin          136
# Embarked       340
# dtype: int64

# %%
titanicDS1.PassengerId.count()
# Out:
# 342

# %%
#PRACTICA mostar en un texto el numero de pasajeros 
#que eran mujeres del titanic
#PRACTICA mostar el numero de pasajeros que eran de clase 2

# %%
titanicSF=titanic["Sex"]=="female"
titanicDSF = titanic[titanicSF]
pasajeras = titanicDSF.PassengerId.count()
print("El numero de pasajeras del titanic era de:",pasajeras)
# Out:
# El numero de pasajeras del titanic era de: 314

# %%
titanicNC2=titanic["Pclass"]==2
titanicDNC2=titanic[titanicNC2]
pasajeros = titanicDNC2.PassengerId.count()
print("El numero de pasajeros de la clase 2 era de:",pasajeros)
# Out:
# El numero de pasajeros de la clase 2 era de: 184

# %% [markdown]
# #Vamos a aprender a filtrarr por mas de una condicion para ello
# #utilizaré el AND y el OR and=& y el or = |
# #si tengo que filtrar mas de una condicion en el mismo campo
# #utilizare el OR, si es de diferente campo el AND (se tienen que cumplir todas las condiciones)

# %%
titanicC23=(titanic["Pclass"]==2)|(titanic["Pclass"]==3)
titanic[titanicC23]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                     Pepe, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#pasajeros que eran mujeres y viajaban en clase 1
titanicC23=(titanic["Pclass"]==1)&(titanic["Sex"]=="female")
titanic=titanicFC1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 3
#       1 #pasajeros que eran mujeres y viajaban en clase 1
#       2 titanicC23=(titanic["Pclass"]==1)&(titanic["Sex"]=="female")
# ----> 3 titanic=titanicFC1
#
# NameError: name 'titanicFC1' is not defined

# %%
#Practica ver en un lista los 5 primeros nombres en orden ascendente 
#de los hombres que no viajaban en clase 1

#practica mostrar en un texto las mujeres que sobrevivieron 
#de la clase 2

#PRACTICA ver en un texto el nmero de pasajeros, cuyo numero 
#de passenger id esta por debajo del numero 50 o por encima del 600

# %%
titanicMC1=(titanic["Sex"]=="male")&(titanic["Pclass"]!=1)
titanicDMC1=titanic[titanicMC1]
titanicDMC1["Name"].head(5).sort_values(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 titanicMC1=(titanic["Sex"]=="male")&(titanic["Pclass"]!=1)
#       2 titanicDMC1=titanic[titanicMC1]
#       3 titanicDMC1["Name"].head(5).sort_values(ascending=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
# ...

# %%
titanicFC2=(titanic["Sex"]=="female")&(titanic["Pclass"]==2)
titanicDFC2=titanic[titanicFC2]
cantidad =titanicDFC2.PassengerId.count()
print("El numero de mujeres de la clase 2 que sobrevivieran era de:")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 titanicFC2=(titanic["Sex"]=="female")&(titanic["Pclass"]==2)
#       2 titanicDFC2=titanic[titanicFC2]
#       3 cantidad =titanicDFC2.PassengerId.count()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
# ...
